# %%
from ipynb.fs.full.mongodb_init import crawlClient

# %%
invsetorDocs = crawlClient['investors']

# %%
for investorDoc in invsetorDocs.find({},{'TXs' : 0}):
    print(investorDoc)
    break
# Out:
# {'_id': '0xb29380ffc20696729b7ab8d093fa1e2ec14dfe2b', 'coins': {'eth': 0.00016}, 'is_shark': False, 'snapshots': {'1669308621': 0, '1669308686': 0, '1669366929': 0, '1669366975': 0, '1669523986': 0, '1669654322': 0, '1669726484': 0, '1669794350': 0, '1669803425': 0, '1669803532': 0, '1669804398': 0, '1669804461': 0, '1669804624': 0, '1669804879': 0, '1669804952': 0, '1669861246': 0, '1669900616': 0, '1669953644': 0, '1670004058': 0, '1670058526': 0, '1670117261': 0, '1670118648': 0, '1670118707': 0, '1670121390': 0, '1670121535': 0, '1670315891': 0, '1670318442': 0, '1670322223': 0, '1670344058': 0, '1670638373': 0, '1670725529': 0, '1670727554': 0, '1670729996': 0, '1670730305': 0, '1670730471': 0, '1670730770': 0, '1670730803': 0, '1670731017': 0, '1670731311': 0, '1670731437': 0, '1670731715': 0, '1670731768': 0, '1670731856': 0, '1670732010': 0, '1670732148': 0, '1670732605': 0, '1670733048': 0, '1670734168': 0, '1670735067': 0, '1670735166': 0, '1670821248': 0, '1670832694': 0, 
# ...
